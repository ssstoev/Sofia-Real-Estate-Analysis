# %%
import sqlite3
import numpy as np
import pandas as pd

# %%
conn = sqlite3.connect("../scraper/data/ads_storage.db")
cursor = conn.cursor()

# %%
query = '''SELECT * FROM ads_appartments'''
cursor.execute(query)
rows = cursor.fetchall()

columns = [description[0] for description in cursor.description]

ads_appartments = pd.DataFrame(data=rows, columns=columns)
ads_appartments.head()
# Out:
#                                              hash_id  \
# 0  ca420156d8e9fbfbd273afed51b5b294de1496404facea...
# 1  528685330d09ed04f6d4182b1b75bff4340766ce5aac35...
# 2  b6c286ce2e6de97589316b15c742cce2b09e5b655ba169...
# 3  9a0fa18467acc9749700e245657c32afdf868653c06d87...
# 4  d4bc76fbc196bf3af9ccb2d2caae76b3b17f5980083ba3...
#
#                                                title  \
# 0  Имот - продава Едностаен апартамент, в София, ...
# 1  Имот - продава Едностаен апартамент, в София, ...
# 2  Имот - продава Двустаен апартамент, в София, Л...
# 3  Имот - продава Двустаен апартамент, в София, К...
# 4  Имот - продава Двустаен апартамент, в София, Л...
#
#                                              img_url  \
# 0  https://www.imoti.net/web/files/obiavi/5945620...
# 1  https://www.imoti.net/web/files/obiavi/5883830...
# 2  https://www.imoti.net/web/files/obiavi/6176496...
# 3  https://www.imoti.net/web/files/obiavi/6157158...
# ...

# %%
ads_appartments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5488 entries, 0 to 5487
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   hash_id                5488 non-null   str
#  1   title                  5488 non-null   str
#  2   img_url                5488 non-null   str
#  3   link                   5488 non-null   str
#  4   neighbourhood          5393 non-null   str
#  5   type_of_estate         5488 non-null   str
#  6   total_price_eur        5400 non-null   float64
#  7   price_m2_eur           5406 non-null   float64
#  8   price_m2_bgn           5406 non-null   float64
#  9   size_m2                5401 non-null   float64
#  10  nr_of_rooms            5211 non-null   float64
#  11  description            5488 non-null   str
#  12  appartment_floor       5322 non-null   float64
#  13  total_floors           5488 non-null   int64
#  14  is_first_floor         5322 non-null   float64
# ...

# %%
ads_appartments[ads_appartments["neighbourhood"] == "дружба 2"]
# Out:
# Empty DataFrame
# Columns: [hash_id, title, img_url, link, neighbourhood, type_of_estate, total_price_eur, price_m2_eur, price_m2_bgn, size_m2, nr_of_rooms, description, appartment_floor, total_floors, is_first_floor, is_last_floor, near_public_transport, furnished, includes_parking, new_building, akt16, energy_class, potreblenie, broker_commision, additional_notes, extras]
# Index: []
#
# [0 rows x 26 columns]

# %%
ads_appartments["link"].tolist()
# Out:
# ['https://www.imoti.net/bg/obiava/prodava/sofia/ovcha-kupel/ednostaen/6176507/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/fondovi-jilishta/ednostaen/5883830/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/sofija-levski/dvustaen/6176496/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava--v-stroej/sofia/karpuzica/dvustaen/6157158/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/sofija-levski/dvustaen/6206616/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava--v-stroej/sofia/gorubljane/dvustaen/6107931/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/sofija-levski/dvustaen/6206618/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/malinova-dolina/dvustaen/6176497/?sid=icNBCK&page=1',
#  'https://www.imoti.net/bg/obiava/prodava/sofia/sofija-studentski-grad/ednostaen/6181566/?sid=icNBCK&page=1',
# ...
